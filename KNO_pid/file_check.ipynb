# %%
import h5py
import numpy as np

# %%
import os

# %%
list_dir = os.listdir('/home/chyoo/KNO_data/elec_h5_cut/')

# %%
for i in range(len(list_dir)):
    file_name = '/home/chyoo/KNO_data/elec_h5_cut/' + str(list_dir[i])
    f = h5py.File(file_name)
    print((np.array(f['event']['pmt_q'])).shape,(np.array(f['event']['pmt_t'])).shape)
# Out:
# (1325, 30912) (1325, 30912)
# (1301, 30912) (1301, 30912)
# (1322, 30912) (1322, 30912)
# (1293, 30912) (1293, 30912)
# (1294, 30912) (1294, 30912)
# (1275, 30912) (1275, 30912)
# (1277, 30912) (1277, 30912)
# (1309, 30912) (1309, 30912)
# (1278, 30912) (1278, 30912)
# (1334, 30912) (1334, 30912)
# (1292, 30912) (1292, 30912)
# (1301, 30912) (1301, 30912)
# (1321, 30912) (1321, 30912)
# (1281, 30912) (1281, 30912)
# (1307, 30912) (1307, 30912)
# (1334, 30912) (1334, 30912)
# (1312, 30912) (1312, 30912)
# (1299, 30912) (1299, 30912)
# (1324, 30912) (1324, 30912)
# (1270, 30912) (1270, 30912)
# (1315, 30912) (1315, 30912)
# (1318, 30912) (1318, 30912)
# (1319, 30912) (1319, 30912)
# (1292, 30912) (1292, 30912)
# (1314, 30912) (1314, 30912)
# (1318, 30912) (1318, 30912)
# (1312, 30912) (1312, 30912)
# (1335, 30912) (1335, 30912)
# (1323, 30912) (1323, 30912)
# (1285, 30912) (1285, 30912)
# (1333, 30912) (1333, 30912)
# (1280, 30912) (1280, 30912)
# (1308, 30912) (1308, 30912)
# ...
