# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
import glob

# %%
## uni = file name
uni = "2024"

path = "/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/*" + uni +"*/train.csv"
train_path = glob.glob(path)
train_list = [file for file in train_path if file.endswith(".csv")]

# %%
for i in range(len(train_list)):
    print(np.sort(np.array(train_list))[i].split('/')[-2])
# Out:
# 20240116_KNO_500_sort1000_SAKER
# 20240116_KNO_500_sort200_SAKER
# 20240116_KNO_sort500_sort200_deep_SAKER
# 20240117_500_1000pmt_sakerv2
# 20240117_500_1000pmt_sakerv3
# 20240117_500_200pmt_sakerv2
# 20240117_500_200pmt_sakerv2_deep
# 20240117_500_200pmt_sakerv3
# 20240117_500_200pmt_sakerv3_deep
# 20240117_KNO_500_sort200_SAKER
# 20240117_KNO_500_sort200_SAKER_deep

# %%
train_list = ['/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240116_KNO_500_sort200_SAKER/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240116_KNO_500_sort1000_SAKER/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240116_KNO_sort500_sort200_deep_SAKER/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240117_KNO_500_sort200_SAKER/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240117_KNO_500_sort200_SAKER_deep/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240117_500_1000pmt_sakerv2/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240117_500_200pmt_sakerv2/train.csv',
 '/home/chyoo/work/KNO_reconstruction/KNO_vertex/result/20240117_500_200pmt_sakerv2_deep/train.csv',
             '/home/chyoo/work/KNO_VRDL/result/20231013_KNO_sort200_SAVR2_posembedding_all/train.csv',
 '/home/chyoo/work/KNO_VRDL/result/20231013_KNO_sort200_SAVR2_posembedding_pos/train.csv',
 '/home/chyoo/work/KNO_VRDL/result/20231109_200_200_SAVER_v2_test_many_fea/train.csv',
 '/home/chyoo/work/KNO_VRDL/result/20231109_200_SAVER_v3_test_many_fea/train.csv',
'/home/chyoo/work/KNO_VRDL/result/20240109_vertexrecon_mu_100_1000_sort/train.csv',
 '/home/chyoo/work/KNO_VRDL/result/20240109_vertexrecon_config_KNO_ele_500_sort1000_more1500_SAVR_batch_v1/train.csv',
 '/home/chyoo/work/KNO_VRDL/result/20240109_vertexrecon_config_KNO_ele_100_1000_sort_re_SAVR_batch_v1/train.csv']

# %%
plt.rcParams['figure.figsize'] = (10, 5)
plt.rcParams['lines.linewidth'] = 1
plt.rcParams['lines.markersize'] = 5
plt.rcParams["legend.loc"] = 'upper right'
plt.rcParams["legend.frameon"] = False
plt.rcParams["legend.loc"] = 'upper left'

ax1 = plt.subplot(1, 2, 1, yscale='log', ylabel='Loss(train)', xlabel='epoch')
ax2 = plt.subplot(1, 2, 2, yscale='log', ylabel='Loss(val)', xlabel='epoch')

for ax in (ax1, ax2):
    ax.grid(which='major', axis='both', linestyle='-.')
    ax.grid(which='minor', linestyle=':')
    ax.set_xlim([0,100])

lines, labels = [], []

for i in range(len(train_list)):
    df = pd.read_csv(train_list[i])

    label = train_list[i]
    l =  ax1.plot(df['loss'], linewidth=2) 
    ax2.plot(df['val_loss'], linewidth=2,label=label.split('/')[-2])
   
    print(i,
          len(df['loss']),
          ' / ',
          "MTL = " + f"{df['loss'].min():.7f}",
          " / ",
          "MTL epoch = " + str("{:04}".format(np.where(df['loss']==df['loss'].min())[0][0])),
          " / ",
          f"{df['val_loss'].min():.7f}",
          " / ",
          "MVL = " + f"{df['val_loss'].min():.7f}",
          " / ",
          "MVL epoch = " + str("{:04}".format(np.where(df['val_loss']==df['val_loss'].min())[0][0])),
          " / ",
          label.split('/')[-2])

    lines.append(l[0])
    labels.append(label)
plt.tight_layout()
# plt.savefig('acc_loss.png',dpi=300)
plt.legend()
plt.show()
plt.close()
# Out:
# 0 60  /  MTL = 31036.9877596  /  MTL epoch = 0059  /  78994.7493447  /  MVL = 78994.7493447  /  MVL epoch = 0044  /  20240116_KNO_500_sort200_SAKER
# 1 8  /  MTL = 18856.7582007  /  MTL epoch = 0007  /  28728.2589268  /  MVL = 28728.2589268  /  MVL epoch = 0007  /  20240116_KNO_500_sort1000_SAKER
# 2 38  /  MTL = 38798.1443511  /  MTL epoch = 0037  /  78258.1687034  /  MVL = 78258.1687034  /  MVL epoch = 0037  /  20240116_KNO_sort500_sort200_deep_SAKER
# 3 3  /  MTL = 98247.8679788  /  MTL epoch = 0002  /  89243.3855197  /  MVL = 89243.3855197  /  MVL epoch = 0002  /  20240117_KNO_500_sort200_SAKER
# 4 1  /  MTL = 248018.5548474  /  MTL epoch = 0000  /  120759.2348941  /  MVL = 120759.2348941  /  MVL epoch = 0000  /  20240117_KNO_500_sort200_SAKER_deep
# 5 1  /  MTL = 80630.9265682  /  MTL epoch = 0000  /  44523.8866312  /  MVL = 44523.8866312  /  MVL epoch = 0000  /  20240117_500_1000pmt_sakerv2
# ...

# %%
# !pwd
# Out:
# /home/chyoo/work/KNO_reconstruction/KNO_vertex
